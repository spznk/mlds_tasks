# %% [markdown]
# У цьому домашньому завданні ми будемо працювати з набором даних Tips. Нижче інформація про нього.
#
# **Про датасет:**
#
# Tips - це датасет, який містить інформацію про рахунки та чайові в ресторані.
#
# **Колонки датасету:**
# - `total_bill` - загальна сума рахунку (долари)
# - `tip` - розмір чайових (долари)
# - `sex` - стать відвідувача (Male/Female)
# - `smoker` - чи курить (Yes/No)
# - `day` - день тижня (Thur/Fri/Sat/Sun)
# - `time` - час відвідування (Lunch/Dinner)
# - `size` - розмір групи (кількість людей)
#
# **Джерело:** Оригінальні дані зібрані в одному з американських ресторанів у 1990-х роках. Скачати і переглянути набір даних можна тут: https://www.kaggle.com/datasets/sakshisatre/tips-dataset
#
# А також ми вже вивантажили файл з даними і завантажили вам у Матеріали до цього модуля.

# %% [markdown]
# **1. Завантаження та огляд**
#
# Завантажте датасет Tips (Чайові) з файла у матеріалах `tips.csv`.
#
# Виведіть (кожен пункт оцінюється в 0.5 бала):
# - Перші 5 рядків
# - Розмір датасету (shape)
# - Назви всіх колонок
# - Інформацію про типи даних (info)

# %%
import pandas as pd

data = pd.read_csv('tips.csv')

# %%
print(f"First 5 rows:\n{data.head(5)}\n")
print(f"Dataset size:\n{data.shape}\n")
print(f"Columns:\n{data.columns}\n")
print(f"Dataset info:\n{data.info}\n")
# Out:
# First 5 rows:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#
# Dataset size:
# (244, 7)
#
# Columns:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')
#
# Dataset info:
# <bound method DataFrame.info of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %% [markdown]
# **2. Базова вибірка даних**
#
# Виберіть та виведіть (кожен пункт оцінюється в 0.5 бала):
# - Колонку `total_bill` (загальний рахунок)
# - Колонки `total_bill` та `tip` (чайові) разом
# - Перші 10 рядків
# - Рядок з індексом 5

# %%
print(f"'total_bill' column:\n{data['total_bill']}\n")
print(f"'total_bill' and 'tip' columns:\n{data[['total_bill', 'tip']]}\n")
print(f"First 10 rows:\n{data.iloc[0:10]}\n")
print(f"Row with index 5:\n{data.iloc[5]}\n")
# Out:
# 'total_bill' column:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64
#
# 'total_bill' and 'tip' columns:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]
#
# First 10 rows:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2
#
# Row with index 5:
# total_bill     25.29
# tip             4.71
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               4
# Name: 5, dtype: object

# %% [markdown]
# **3. Фільтрація даних**
#
# Відфільтруйте повний набір даних та виведіть (кожен пункт оцінюється в 0.5 бала):
# - Всі рахунки більше 20 доларів (`total_bill > 20`)
# - Всі відвідувачі-жінки (`sex == 'Female'`)
# - Рахунки на вечерю (`time == 'Dinner'`)
# - Рахунки на вечерю з сумою чеку більше 30 доларів
#
# Для виведення результатів фільтрації:
# - зберегти результат у окрему змінну
# - показати кількість записів у відфільтрованому наборі
# - вивести перші 5 записів відфільтрованого набору.

# %%
# Всі рахунки більше 20 доларів
data_bill_over_20 = data[data['total_bill'] > 20]
print(f"Count for bill > 20: {len(data_bill_over_20)}")
print(f"First 5 rows for bill > 20:\n{data_bill_over_20.head(5)}\n")

# Всі відвідувачі-жінки
data_female = data[data['sex'] == 'Female']
print(f"Count for female visitors: {len(data_female)}")
print(f"First 5 rows for female visitors:\n{data_female.head(5)}\n")

# Рахунки на вечерю
data_dinner = data[data['time'] == 'Dinner']
print(f"Count for dinner: {len(data_dinner)}")
print(f"First 5 rows for dinner:\n{data_dinner.head(5)}\n")

# Рахунки на вечерю з сумою чеку більше 30 доларів
data_dinner_over_30 = data[(data['time'] == 'Dinner') & (data['total_bill'] > 30)]
print(f"Count for dinner: {len(data_dinner_over_30)}")
print(f"First 5 rows for dinner:\n{data_dinner_over_30.head(5)}\n")
# Out:
# Count for bill > 20: 97
# First 5 rows for bill > 20:
#    total_bill   tip     sex smoker  day    time  size
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 7       26.88  3.12    Male     No  Sun  Dinner     4
#
# Count for female visitors: 87
# First 5 rows for female visitors:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 16       10.33  1.67  Female     No  Sun  Dinner     3
#
# Count for dinner: 176
# First 5 rows for dinner:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#
# Count for dinner: 27
# First 5 rows for dinner:
#     total_bill   tip     sex smoker  day    time  size
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 23       39.42  7.58    Male     No  Sat  Dinner     4
# 39       31.27  5.00    Male     No  Sat  Dinner     3
# 44       30.40  5.60    Male     No  Sun  Dinner     4
# 47       32.40  6.00    Male     No  Sun  Dinner     4

# %% [markdown]
# ---
#
# **4. Описова статистика**
#
# Обчисліть (кожен пункт оцінюється в 0.5 бала):
# - Середній розмір рахунку на всьому наборі даних
# - Максимальні чайові
# - Кількість пропущених значень у всіх колонках
# - Скільки в наборі даних рахунків за обіди і за вечері

# %%
print(f"Mean total bill: {data['total_bill'].mean()}\n")
print(f"Max tip: {data['tip'].max()}\n")
print(f"Number of null values:\n{data.isnull().sum()}\n")
print(f"Number of different meal times:\n{data['time'].value_counts()}")
# Out:
# Mean total bill: 19.78594262295082
#
# Max tip: 10.0
#
# Number of null values:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64
#
# Number of different meal times:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %% [markdown]
# ---
#
# **5. Статистика із групуванням**
#
# Обчисліть (кожен пункт оцінюється в 0.5 бала):
# - Середній рахунок за статтю (groupby `sex`)
# - Середні чайові за днем тижня (groupby `day`)
# - Скільки відвідувачів у кожен день

# %%
print(f"Середній рахунок за статтю:\n{data.groupby('sex')['total_bill'].mean()}\n")
print(f"Середні чайові за днем тижня:\n{data.groupby('day')['tip'].mean()}\n")
print(f"Скільки відвідувачів у кожен день:\n{data.groupby('day')['total_bill'].count()}\n")
# Out:
# Середній рахунок за статтю:
# sex
# Female    18.056897
# Male      20.744076
# Name: total_bill, dtype: float64
#
# Середні чайові за днем тижня:
# day
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Thur    2.771452
# Name: tip, dtype: float64
#
# Скільки відвідувачів у кожен день:
# day
# Fri     19
# Sat     87
# Sun     76
# Thur    62
# Name: total_bill, dtype: int64

# %% [markdown]
# ---
#
# **6. Створення нової колонки**
#
# Створіть нову колонку `tip_percentage` - відсоток чайових від загальної суми рахунку.
# Виведіть перші 10 рядків з новою колонкою.

# %%
data['tip_percentage'] = data['tip'] / data['total_bill'] * 100
print(data.head(10))
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_percentage
# 0       16.99  1.01  Female     No  Sun  Dinner     2        5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3       16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3       16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2       13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4       14.680765
# 5       25.29  4.71    Male     No  Sun  Dinner     4       18.623962
# 6        8.77  2.00    Male     No  Sun  Dinner     2       22.805017
# 7       26.88  3.12    Male     No  Sun  Dinner     4       11.607143
# 8       15.04  1.96    Male     No  Sun  Dinner     2       13.031915
# 9       14.78  3.23    Male     No  Sun  Dinner     2       21.853857

# %% [markdown]
# ---
#
# **7. Сортування**
#
# Відсортуйте датасет і виведіть результат сортування в кожному випадку окремо (кожен пункт оцінюється в 0.5 бала):
# - За розміром рахунку (зростання)
# - За чайовими (спадання)
#
# Додатково виведіть топ-5 найбільших чайових використовуючи метод `nlargest`.

# %%
# За розміром рахунку (зростання)
data_bill_asc = data.sort_values('total_bill')
print(data_bill_asc)
# Out:
#      total_bill    tip     sex smoker   day    time  size  tip_percentage
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1       32.573290
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2       17.391304
# 111        7.25   1.00  Female     No   Sat  Dinner     1       13.793103
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2       71.034483
# 149        7.51   2.00    Male     No  Thur   Lunch     2       26.631158
# ..          ...    ...     ...    ...   ...     ...   ...             ...
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3        7.717751
# 156       48.17   5.00    Male     No   Sun  Dinner     6       10.379905
# 59        48.27   6.73    Male     No   Sat  Dinner     4       13.942407
# 212       48.33   9.00    Male     No   Sat  Dinner     4       18.621974
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3       19.681165
#
# [244 rows x 8 columns]

# %%
# За чайовими (спадання)
data_tip_desc = data.sort_values('tip', ascending = False)
print(data_tip_desc)
# Out:
#      total_bill    tip     sex smoker   day    time  size  tip_percentage
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3       19.681165
# 212       48.33   9.00    Male     No   Sat  Dinner     4       18.621974
# 23        39.42   7.58    Male     No   Sat  Dinner     4       19.228818
# 59        48.27   6.73    Male     No   Sat  Dinner     4       13.942407
# 141       34.30   6.70    Male     No  Thur   Lunch     6       19.533528
# ..          ...    ...     ...    ...   ...     ...   ...             ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2        5.944673
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2        7.936508
# 111        7.25   1.00  Female     No   Sat  Dinner     1       13.793103
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1       32.573290
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2       17.391304
#
# [244 rows x 8 columns]

# %%
# Топ-5 найбільших чайових
data_largest_tips = data.nlargest(5, 'tip')
print(data_largest_tips)
# Out:
#      total_bill    tip   sex smoker   day    time  size  tip_percentage
# 170       50.81  10.00  Male    Yes   Sat  Dinner     3       19.681165
# 212       48.33   9.00  Male     No   Sat  Dinner     4       18.621974
# 23        39.42   7.58  Male     No   Sat  Dinner     4       19.228818
# 59        48.27   6.73  Male     No   Sat  Dinner     4       13.942407
# 141       34.30   6.70  Male     No  Thur   Lunch     6       19.533528
