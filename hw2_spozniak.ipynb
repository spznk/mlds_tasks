# %% [markdown]
# # HW2

# %% [markdown]
# ### 1. Списки - базові операції

# %%
temperatures = [22, 25, 19, 23, 26, 20, 21, 22]

# %%
print(temperatures[0])
print(temperatures[-1])
# Out:
# 22
# 22

# %%
temperatures.append(24)
temperatures.remove(19)
temperatures
# Out:
# [22, 25, 23, 26, 20, 21, 22, 24]

# %%
print(len(temperatures))
print(sum(temperatures))
print(max(temperatures))
# Out:
# 8
# 183
# 26

# %% [markdown]
# ### 2. Словники - базові операції

# %%
me = {
    'name': 'Serhii',
    'age': 35,
    'city': 'Wroclaw'
}

# %%
print(me['name'])
# Out:
# Serhii

# %%
me['age'] = 21
me['hobby'] = 'programming'

# %%
print(me.keys())
print(me.values())
# Out:
# dict_keys(['name', 'age', 'city', 'hobby'])
# dict_values(['Serhii', 21, 'Wroclaw', 'programming'])
