# %% [markdown]
# В цьому домашньому завданні відпрацюємо з вами знання, отримані в модулі зі статистики.
#
# **Завдання 1.** Ми обговорили з Вами на лекції, що велика літера Сігма грецького алфавіту позначає в математиці суму. Знайдіть з використанням Python $\Sigma x$, $\Sigma x^2$, та $\Sigma (x-1)^2$ для наступного набору даних:
# `1 3 4`
# Виведіть результат кожного обчислення на екран.

# %%
data = [1, 3, 4]

list_sum_1 = sum(data)
list_sum_2 = sum([x**2 for x in data])
list_sum_3 = sum([(x-1)**2 for x in data])

print(f"Sum of x: {list_sum_1}")
print(f"Sum of x^2: {list_sum_2}")
print(f"Sum of (x - 1)^2: {list_sum_3}")
# Out:
# Sum of x: 8
# Sum of x^2: 26
# Sum of (x - 1)^2: 13

# %% [markdown]
# **Завдання 2.** Ми зібрали дані про суму покупок в гривнях 20ма випадково обраними клієнтами в нашому магазині (всього клієнтів у нас більше) за минулий місяць. Вони представлені в змінній `sum_purchases`. Знайдіть **вибіркове середнє** для цих даних кожним з зазначених методів:
#
#   2.1. без використання жодних бібліотек, користуючись тільки Python.
#   2.2. використовуючи відповідний метод бібліотеки `numpy`.
#
#   Виведіть результат обчислень в кожному з випадків на екран та порівняйте результати. Вони співпадають?

# %%
sum_purchases = [ 316,  493,  367,  153,  224,  121,  322,  450,  196,  397,  281,
  239,  484,  124,  223,  448,  432,  255, 4310, 3524]

# %%
mean_x = sum(sum_purchases)/len(sum_purchases)
mean_x
# Out:
# 667.95

# %%
import numpy as np

mean_x_np = np.mean(sum_purchases)
mean_x_np
# Out:
# np.float64(667.95)

# %%
print(mean_x == mean_x_np)
# Out:
# True

# %% [markdown]
# **Завдання 3.** Для того ж набору даних в змінній `sum_purchases` обчисліть **медіану** кожним з зазначених методів:
#
#   3.1. без використання жодних бібліотек, користуючись тільки Python.
#   3.2. використовуючи відповідний метод бібліотеки numpy.
#
# Виведіть результат обчислень в кожному з випадків на екран. Порівняйте результати зі значенням вибіркового середнього. Напишіть коментар, для яких задач ви б використовували вибіркове середнє, а для яких - медіану?

# %%
def get_list_median(num_list):
    list_len = len(num_list)
    sorted_num_list = sorted(num_list)

    if(list_len % 2 == 0):
        list_median = (sorted_num_list[list_len//2 - 1] + sorted_num_list[list_len//2]) / 2
    else:
        list_median = sorted_num_list[list_len//2]

    return list_median

median_x = get_list_median(sum_purchases)
median_x
# Out:
# 319.0

# %%
median_x_np = np.median(sum_purchases)
median_x_np
# Out:
# np.float64(319.0)

# %% [markdown]
# Я б використовував медіану для задач, де потрібно передбачити наступне значення.
# А вибіркове середнє – де дані з цього списку потрібні для обрахунку інших значень.
#
# А також медіану краще використовувати, коли є сильна розбіжність даних, а середнє – коли набір можливих значень відомий наперед.

# %%
print(median_x == median_x_np)
# Out:
# True

# %% [markdown]
# **Завдання 4**. Обчислість стандартне відхилення наведеної вибірки в змінній `sum_purchases` кожним з зазначених методів:
#
#   4.1. без використання жодних бібліотек, користуючись тільки Python.
#   4.2. використовуючи відповідний метод бібліотеки numpy.
#
# Виведіть результат обчислень в кожному з випадків на екран.

# %%
import math

x_minus_mean_square = [(x-mean_x) ** 2 for x in sum_purchases]
s_x = math.sqrt(sum(x_minus_mean_square) / (len(sum_purchases)-1))
s_x
# Out:
# 1124.5433447451132

# %%
s_x = np.std(sum_purchases, ddof=1)
s_x
# Out:
# np.float64(1124.5433447451132)

# %% [markdown]
# **Завдання 5**. Ми провели дослідження віку студентів-першокурсників. Виявилось, що
# - 10 студентів мають вік 16 років
# - 25 студентів - 17 років
# - 20 студентів - 18 років
# - 2 студенти - 20 років
#
# Обчислість середнє значення для цієї вибірки будь-яким способом - на чистому Python або з numpy - та виведіть результат на екран.

# %%
student_age = [16]*10 + [17]*25 + [18]*20 + [20]*2
print(f"Students age values: {student_age}\n")

mean_age = sum(student_age) / len(student_age)
print(f"Mean students age: {mean_age}")
# Out:
# Students age values: [16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 20, 20]
#
# Mean students age: 17.280701754385966

# %% [markdown]
# **Завдання 6**. Крім даних про суму покупок, ми зібрали ще дані про кількість відвідувань кожного з кожного покупця, які знаходяться в змінній `visits`. Обчисліть коефіцієнт кореляції Пірсона для суми покупок і кількості відвідувань кожним з зазначених методів:
#
#   6.1. без використання жодних бібліотек, користуючись тільки Python.
#   6.2. використовуючи відповідний метод бібліотеки numpy.
#
# Виведіть результат на екран. Проаналізуйте результат.
#
# Виведіть додатково графік розсіювання викликавши код нижче і зробіть заключення, чи варто щось змінити при підрахунку кореляції, аби коефіцієнт Пірсона показував коректну оцінку лінійної залежності?

# %%
visits = [ 6,  2, 10,  3,  9,  9,  2,  3,  6,  6, 10,  2,  5, 10,  3,  5,  4,
        7,  4,  2]

# %%
mean_y = sum(visits) / len(visits)

print(f"Mean for purchase sum: {mean_x}")
print(f"Mean for visits: {mean_y}")
# Out:
# Mean for purchase sum: 667.95
# Mean for visits: 5.4

# %%
xy = [(sum_purchases[i]-mean_x) * (visits[i]-mean_y) for i in range(len(visits))]
cov_xy = sum(xy) / (len(visits)-1)
print(f"Covariation for purchases sum and visits: {cov_xy}")
# Out:
# Covariation for purchases sum and visits: -990.1368421052633

# %%
y_minus_mean_square = [(y-mean_y) ** 2 for y in visits]
s_y = math.sqrt(sum(y_minus_mean_square) / (len(visits)-1))

print(f"Standart deviation for purchases sum: {s_x}")
print(f"Standart deviation for visits: {s_y}")
# Out:
# Standart deviation for purchases sum: 1124.5433447451132
# Standart deviation for visits: 2.9091507170885533

# %%
r_xy = cov_xy / (s_x * s_y)

print(f"Pirson corellation coefficient: {r_xy}")
# Out:
# Pirson corellation coefficient: -0.30265844687666454

# %%
# Calculating with Numpy
r_xy_np = np.corrcoef(sum_purchases, visits)

print(f"Corellation coefficient calculated with Numpy:\n{r_xy_np}")
# Out:
# Corellation coefficient calculated with Numpy:
# [[ 1.         -0.30265845]
#  [-0.30265845  1.        ]]

# %%
print(r_xy.round(8) == r_xy_np[1][0].round(8))
# Out:
# True

# %%
import matplotlib.pyplot as plt

plt.scatter(sum_purchases, visits)
plt.title('Scatter Plot of Purchases vs. Visits')
plt.xlabel('Sum of Purchases')
plt.ylabel('Number of Visits');

# %% [markdown]
# **Висновок:** Основна маса значень розташована у лівій частині графіка розсіювання. І тільки дві точки лежать далеко в правій частині. Схоже вони є викидами і для більш чіткої картини варто їх усунути.

# %% [markdown]
# **Завдання 7**. В попередньому завданні ми помітили, що викиди нам заважають отримати "правдиве" значення кореляції. Давайте вилучимо записи, які відповідають значенням з викидами в сумі покупок і обчисліть коеф. кореляції. Для цього поставте `threshold`, який дорінює середньому значенню + 2 стандартних вдіхилля суми покупок і всі значення, які більше за нього, будемо вважати викидами (є і інші правила для визначення викидів - з ним и познайомимось пізніше).
#
# Вилучіть значення з обох масивів і обчисліть коеф. кореляції Пірсона з допомогою `numpy` для кількості візитів і суми покупок без записів-викидів. Виведіть результат на екран, побудуйте діаграму розсіювання і проаналізуйте результат: що можемо сказати про залежність в даних?

# %%
threshold = mean_x + 2*s_x
print(f"Threshold: {threshold}")

sum_purchases_clean = []
visits_clean = []

for i in range(len(sum_purchases)):
    if sum_purchases[i] <= threshold:
        sum_purchases_clean.append(sum_purchases[i])
        visits_clean.append(visits[i])

print(f"Cleaned purchases sum list: {sum_purchases_clean}")
print(f"Cleaned visits list: {visits_clean}")
# Out:
# Threshold: 2917.0366894902263
# Cleaned purchases sum list: [316, 493, 367, 153, 224, 121, 322, 450, 196, 397, 281, 239, 484, 124, 223, 448, 432, 255]
# Cleaned visits list: [6, 2, 10, 3, 9, 9, 2, 3, 6, 6, 10, 2, 5, 10, 3, 5, 4, 7]

# %%
r_clean = np.corrcoef(sum_purchases_clean, visits_clean)
print(f"Correlation coeficient for cleaned data:\n{r_clean}")
# Out:
# Correlation coeficient for cleaned data:
# [[ 1.         -0.36852121]
#  [-0.36852121  1.        ]]

# %%
plt.scatter(sum_purchases_clean, visits_clean)
plt.xlabel("Purchases sum")
plt.ylabel("Visits")
plt.show()

# %% [markdown]
# **Висновок:** Коефіцієнт кореляції показує деяку обернену залежність між сумами покупок і кількостями візитів. Але на графіку розсіювання цю залежність ледь видно. Можливо на більшій кількості даних було би видно краще.
