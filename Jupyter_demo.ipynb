# %% [markdown]
# # **Hello!**
# #### It's me you're looking for.
# ###### *Hello!*

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
5 * 5
# Out:
# 25

# %%
# !ls
# Out:
# Jupyter_demo.ipynb lala.py

# %%
# !pwd
# Out:
# /Users/spozniak/Notebooks

# %%
import time

for i in range(3):
    print(i)
    time.sleep(5)
# Out:
# 0
# 1
# 2

# %%
sp_list = [1, 1, 2, 3, 5]

# %%
sp_list
# Out:
# [1, 1, 2, 3, 5]

# %%
[x**2 for x in range(-5, 7)]
# Out:
# [25, 16, 9, 4, 1, 0, 1, 4, 9, 16, 25, 36]

# %% [markdown]
# - djdjdj
#   - kkkk
#     - ndnnd
# - jhgjggh

# %%
h = "Ola!"

# %%
2 + 2
print(4 + 4)
print(h)
# Out:
# 8
# Ola!

# %%
h
# Out:
# 'Ola!'

# %%
h.lower()
# Out:
# 'ola!'

# %%
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.plot(np.cos(range(25)))

# %%
a = 15
b = 31
c = a / b

# %%
c
# Out:
# 0.4838709677419355
