# %% [markdown]
# # HW1

# %% [markdown]
# ### 1. Створення змінних

# %%
name = 'Serhii'
age = 35
height = 1.65
is_student = False

# %%
print(name)
print(age)
print(height)
print(is_student)
# Out:
# Serhii
# 35
# 1.65
# False

# %% [markdown]
# ### 2. Арифметичні операції

# %%
var1 = 15
var2 = 4

# %%
print(var1 + var2)
print(var1 - var2)
print(var1 / var2)
print(var1 * var2)
print(var1 // var2)
print(var1 % var2)
print(var1 ** var2)
# Out:
# 21
# 13
# 4.25
# 68
# 4
# 1
# 83521

# %% [markdown]
# ### 3. Робота з рядками

# %%
last_name = 'Pozniak'
full_name = name + ' ' + last_name

# %%
print(full_name.upper())
print(full_name.lower())
print(len(full_name))
print(f'Мене звати {name}, мені {age} років')
# Out:
# SERHII POZNIAK
# serhii pozniak
# 14
# Мене звати Serhii, мені 35 років
